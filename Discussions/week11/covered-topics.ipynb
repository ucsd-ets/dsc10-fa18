# %%
from datascience import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("fivethirtyeight")

# %% [markdown]
# General structure for this session:
#
# - What have we learned? (quick list)
# - Practice Final #5 solution
# - Q&A

# %% [markdown]
# # Let's take a trip down memory lane
# ---

# %% [markdown]
# We've covered Chapters 1–16 from the textbook:
#
# 1. **Data Science**
#    - Use of data science
#    - Inference from literature
#
#
# 2. **Causality and Experiments**
#    - John Snow's "Grand Experiment"
#    - Randomization
#
#
# 3. **Programming in Python**
#    - Variables
#    - Expressions (computations)
#    - Tables
#
#
# 4. **Data Types**
#    - Strings
#    - Numbers
#    - Comparisons
#
#
# 5. **Sequences**
#    - Arrays
#    - Ranges
#
#
# 6. **Tables**
#    - Sorting
#    - Selecting what you want
#
#
# 7. **Visualization**
#    - Categorical versus Numerical
#    - Plots
#
#
# 8. **Functions and Tables**
#    - Python functions
#    - Table.apply
#    - Table.join
#
#
# 9. **Randomness**
#    - Conditionals
#    - Iteration
#    - Simulation
#    - Probability
#
#
# 10. **Sampling and Empirical Distributions**
#     - Empircal Distributions
#     - Sampling
#     - Statistics
#
#
# 11. **Testing Hypotheses**
#     - Null and Alternatives Models
#
#
# 12. **Comparing Two Samples**
#     - A/B Testing
#     - Causality
#
#
# 13. **Estimation**
#     - Percentiles
#     - Bootstrapping
#     - Confidence Intervals
#
#
# 14. **Why the Mean Matters**
#     - Properties of the Mean
#     - Variance and Standard Deviation
#     - Normal Curve
#     - Central Limit Theorem
#     - Variability of the Sample Mean
#     - Choosing Sample Size
#
#
# 15. **Prediction**
#     - Correlation
#     - Regression
#     - RMSE
#
#
# 16. **Inference for Regression**

# %% [markdown]
# ---
#
# Alternatively, we could break it up by week.  This is roughly what we covered and when:
#
# **Week 0:**
# - Cause and Effect
# - Experiments
#
# **Week 1:**
# - Jupyter and Python basics
# - Arrays and Tables
# - Table.column
#
# **Week 2:**
# - Selecting data (take, with_column, where, are.predicates)
# - Visualizations (scatter, bar graphs)
# - Categorical vs numerical data
#
# **Week 3:**
# - Overlaying plots, histograms;
# - Python functions
# - Apply
# - Group
#
# **Week 4:**
# - Table.join
# - Python conditional statements and operators (if/elif/else, and/or)
# - Iterators (for loops)
# - Table.pivot
# - Random chance and sampling
# - np.count_nonzero()
# - Histogram bins
# - Simulations
# - Probabilities
#
# **Week 5:**
# - Probability Distributions
# - Empirical distributions
# - Law of Large Numbers / Law of Averages
#
# **Week 6:**
# - Models (and statistics from the model)
# - Bias and Variance
# - (Estimation and Assessment)
# - Hypothesis testing
# - Total Variational Distance
# - Null and alternate hypothesis, p-value
#
# **Week 7:**
# - A/B Testing
# - Bootstrapping
# - Confidence Intervals
# - Percentiles
# - Estimation from CI
#
# **Week 8:**
# - Duality of CI and Hypothesis Testing
# - Sample Mean
# - Standard deviations
# - Normal distribution
# - Central Limit Theorem
#
# **Week 9:**
# - The normal curve
# - Standard units and area
# - STD vs population STD
# - Normal Confidence Intervals
# - Bootstraps and CIs revisited
#
# **Week 10:**
# - Prediction
# - Correlation (Correlation Coefficient r)
# - Regression
# - Outliers
# - Error in estimation (RMSE)
# - Heteroscedasticity
# - Residuals
# - Inference
# - Prediction intervals varying with inputs
